# %%
import pandas as pd
df=pd.read_excel("British Airways Summer Schedule Dataset - Forage Data Science Task 1.xlsx")
df
# Out:
#      FLIGHT_DATE FLIGHT_TIME TIME_OF_DAY AIRLINE_CD FLIGHT_NO  \
# 0     2025-09-02    14:19:00   Afternoon         BA    BA5211
# 1     2025-06-10    06:42:00     Morning         BA    BA7282
# 2     2025-10-27    15:33:00   Afternoon         BA    BA1896
# 3     2025-06-15    18:29:00     Evening         BA    BA5497
# 4     2025-08-25    20:35:00     Evening         BA    BA1493
# ...          ...         ...         ...        ...       ...
# 9995  2025-06-07    22:04:00     Evening         BA    BA7039
# 9996  2025-04-22    15:15:00   Afternoon         BA    BA9712
# 9997  2025-08-16    06:11:00     Morning         BA    BA7513
# 9998  2025-10-24    22:02:00     Evening         BA    BA9958
# 9999  2025-05-28    22:00:00     Evening         BA    BA8374
#
#      DEPARTURE_STATION_CD ARRIVAL_STATION_CD ARRIVAL_COUNTRY ARRIVAL_REGION  \
# 0                     LHR                LAX             USA  North America
# ...

# %%
df["TIME_OF_DAY"].unique()
df["HAUL"].unique()
df["ARRIVAL_REGION"].unique()
# Out:
# array(['North America', 'Europe', 'Asia', 'Middle East'], dtype=object)

# %%
df["TOTAL_PASSENGERS"]= df["FIRST_CLASS_SEATS"] + df["BUSINESS_CLASS_SEATS"] + df["ECONOMY_SEATS"]
df["TIER1S"]=df["TIER1_ELIGIBLE_PAX"]
df["TIER2S"]=df["TIER2_ELIGIBLE_PAX"]
df["TIER3S"]=df["TIER3_ELIGIBLE_PAX"]
df["Total"]=df["TOTAL_PASSENGERS"]+df["TIER1_ELIGIBLE_PAX"]+df["TIER2_ELIGIBLE_PAX"]+df["TIER3_ELIGIBLE_PAX"]
grouped=df.groupby(["TIME_OF_DAY", "HAUL", "ARRIVAL_REGION"])["Total"].sum()
grouped
# Out:
# TIME_OF_DAY  HAUL   ARRIVAL_REGION
# Afternoon    LONG   Asia               50533
#                     Middle East        53251
#                     North America     208001
#              SHORT  Europe            298111
# Evening      LONG   Asia               67530
#                     Middle East        66263
#                     North America     259030
#              SHORT  Europe            390827
# Lunchtime    LONG   Asia               24434
#                     Middle East        25469
#                     North America      92934
#              SHORT  Europe            166534
# Morning      LONG   Asia               80992
#                     Middle East        82127
#                     North America     321573
#              SHORT  Europe            452270
# Name: Total, dtype: int64

# %%
df["Total"]=df["TOTAL_PASSENGERS"]+df["TIER1_ELIGIBLE_PAX"]+df["TIER3_ELIGIBLE_PAX"]
df["TIER1_ELIGIBLE_PCT"]=(df["TIER1_ELIGIBLE_PAX"]/df["Total"])*100
df["TIER2_ELIGIBLE_PCT"]=(df["TIER2_ELIGIBLE_PAX"]/df["Total"])*100
df["TIER3_ELIGIBLE_PCT"]=(df["TIER3_ELIGIBLE_PAX"]/df["Total"])*100



grouped=df.groupby(["TIME_OF_DAY", "HAUL", "ARRIVAL_REGION"])[["Total","TIER1_ELIGIBLE_PCT", "TIER2_ELIGIBLE_PCT", "TIER3_ELIGIBLE_PCT", "Total"]
].mean()
grouped=grouped.round(4)
grouped.to_excel("Final_Result_Lounge_Eligibility_Lookup_Table.xlsx")
grouped
# Out:
#                                      Total  TIER1_ELIGIBLE_PCT  \
# TIME_OF_DAY HAUL  ARRIVAL_REGION
# Afternoon   LONG  Asia            324.0329              0.1581
#                   Middle East     326.9937              0.1958
#                   North America   323.1561              0.1864
#             SHORT Europe          210.4722              0.2929
# Evening     LONG  Asia            320.0388              0.1950
#                   Middle East     322.0896              0.2102
#                   North America   322.9502              0.2037
#             SHORT Europe          211.1834              0.2791
# Lunchtime   LONG  Asia            318.4133              0.1490
#                   Middle East     314.7089              0.1733
#                   North America   322.6904              0.1750
#             SHORT Europe          211.8045              0.3324
# Morning     LONG  Asia            321.5528              0.2026
# ...
